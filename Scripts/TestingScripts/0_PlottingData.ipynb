# %% [markdown]
# # Making plots using the COSIMA Cookbook
#
# This notebook uses ACCESS-OM2-01 outputs to create some basic plots using the COSIMA Cookbook.
#
#
# **Requirements:** We strongly suggest that you select the `conda/analysis3-20.01` (or later) kernel.

# %% [markdown]
# **Loading relevant libraries**

# %%
#Make plots appear in line
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import netCDF4 as nc
import xarray as xr
import numpy as np
from dask.distributed import Client
import pandas as pd

# %% [markdown]
# Libraries used to make maps

# %%
import cmocean as cm                              # Nice colormaps
from collections import OrderedDict               # We often use this to organise our experiments
import cftime                                     # In case you need to work with time axes
import glob                                       # If you need to search file systems
import cartopy.crs as ccrs                        # For making maps.
import cartopy.feature as cft                     # For adding features to maps

# %% [markdown]
# It's often a good idea to start a cluster with multiple cores for you to work with. This is the easiest way to do that:

# %%
client = Client(n_workers=4)

# %% [markdown]
# Accessing default database of experiments from which data will be loaded.

# %%
session = cc.database.create_session()

# %% [markdown]
# ## Database experiment list
# * Accessing list of all experiments including in the database loaded.
# * Searching for outputs of the 0.1 degree model
# * Keeping only outputs that include wind forcing identified as *IAF*
# * Include latest experiment cycle *jra55v140* - Data from this experiment could not be loaded, so looking for previous run.

# %%
#Allowing all elements in the list to show in the console
pd.set_option("display.max_rows", None)

#Extracting the entire list of experiments in the database
explist = cc.querying.get_experiments(session, all = True) #the 2nd argument provides additional info about each experiment

#Searching for experiments that meet the criteria listed above. 
explist[explist['experiment'].str.contains("01deg.*jra55v1.*iaf*")]
# Out:
#                         experiment      contact                   email  \
# 15  01deg_jra55v13_ryf9091_qian_wp      Qian Li    qian.li5@unsw.edu.au
# 20              01deg_jra55v13_iaf         None                    None
# 21             01deg_jra55v140_iaf  Andrew Kiss  andrew.kiss@anu.edu.au
# 22      01deg_jra55v140_iaf_cycle2  Andrew Kiss  andrew.kiss@anu.edu.au
#
#       created                                        description  \
# 15 2020-03-13                       Wind perturbation experiment
# 20        NaT                                               None
# 21 2020-06-09  0.1 degree ACCESS-OM2 global model configurati...
# 22 2020-08-20  0.1 degree ACCESS-OM2 global model configurati...
#
#                                                 notes  \
# 15                                               None
# 20                                               None
# 21  Source code: https://github.com/COSIMA/access-...
# 22  Run configuration and history: https://github....
#
#                                              root_dir  ncfiles
# 15  /g/data/ik11/outputs/access-om2-01/01deg_jra55...       36
# 20  /g/data/hh5/tmp/cosima/access-om2-01/01deg_jra...     2700
# 21  /g/data/cj50/access-om2/raw-output/access-om2-...    26168
# 22  /g/data/cj50/access-om2/raw-output/access-om2-...    25198

# %%
#Removing experiment list variable - no longer needed
del explist

# %% [markdown]
# ## Experiment variables list

# %%
#Querying about the temporal frequency available for the variables in this experiment
cc.querying.get_frequencies(session, experiment = '01deg_jra55v140_iaf')
# Out:
#    frequency
# 0       None
# 1    1 daily
# 2  1 monthly
# 3     static

# %%
#Getting a list variables that have "temperature" in its long_name and that have a monthly frequency
tempvar01deg = cc.querying.get_variables(session, experiment = '01deg_jra55v140_iaf', frequency = '1 monthly')
tempvar01deg[tempvar01deg['long_name'].str.lower().str.match('.*temp.*')]
# Out:
#                      name                                          long_name  \
# 7                  Tsfc_m                       snow/ice surface temperature
# 29             diff_cbt_t   total vert diff_cbt(temp) (w/o neutral included)
# 73               pot_temp                              Potential temperature
# 96           surface_temp                           Conservative temperature
# 97       surface_temp_min                           Conservative temperature
# 104                  temp                           Conservative temperature
# 105        temp_int_rhodz  vertical sum of Conservative temperature * rho...
# 106        temp_xflux_adv                              cp*rho*dzt*dyt*u*temp
# 107  temp_xflux_adv_int_z                    z-integral of cp*rho*dyt*u*temp
# 108        temp_yflux_adv                              cp*rho*dzt*dxt*v*temp
# 109  temp_yflux_adv_int_z                    z-integral of cp*rho*dxt*v*temp
#
#      frequency                                             ncfile  # ncfiles  \
# 7    1 monthly               output243/ice/OUTPUT/iceh.2018-12.nc        732
# 29   1 monthly  output243/ocean/ocean-3d-diff_cbt_t-1-monthly-...        244
# 73   1 monthly  output243/ocean/ocean-3d-pot_temp-1-monthly-me...        244
# 96   1 monthly  output243/ocean/ocean-2d-surface_temp-1-monthl...        244
# 97   1 monthly  output243/ocean/ocean-2d-surface_temp-1-monthl...        244
# 104  1 monthly  output243/ocean/ocean-3d-temp-1-monthly-mean-y...        272
# 105  1 monthly  output243/ocean/ocean-2d-temp_int_rhodz-1-mont...        244
# 106  1 monthly  output243/ocean/ocean-3d-temp_xflux_adv-1-mont...        244
# 107  1 monthly  output243/ocean/ocean-2d-temp_xflux_adv_int_z-...        244
# 108  1 monthly  output243/ocean/ocean-3d-temp_yflux_adv-1-mont...        244
# 109  1 monthly  output243/ocean/ocean-2d-temp_yflux_adv_int_z-...        244
#
#               time_start             time_end
# 7    1958-01-01 00:00:00  2019-01-01 00:00:00
# 29   1958-01-01 00:00:00  2019-01-01 00:00:00
# 73   1958-01-01 00:00:00  2019-01-01 00:00:00
# 96   1958-01-01 00:00:00  2019-01-01 00:00:00
# 97   1958-01-01 00:00:00  2019-01-01 00:00:00
# 104  1958-01-01 00:00:00  2019-01-01 00:00:00
# 105  1958-01-01 00:00:00  2019-01-01 00:00:00
# 106  1958-01-01 00:00:00  2019-01-01 00:00:00
# 107  1958-01-01 00:00:00  2019-01-01 00:00:00
# 108  1958-01-01 00:00:00  2019-01-01 00:00:00
# 109  1958-01-01 00:00:00  2019-01-01 00:00:00

# %%
#Getting a list variables that have "salinity" in its long_name and that have a monthly frequency
salvar01deg = cc.querying.get_variables(session, experiment = '01deg_jra55v140_iaf', frequency='1 monthly')
salvar01deg[salvar01deg['long_name'].str.lower().str.match('.*sal.*')]
# Out:
#                      name                                        long_name  \
# 50             fsalt_ai_m                           salt flux ice to ocean
# 51                fsalt_m                       salt flux ice to ocn (cpl)
# 78                   salt                               Practical Salinity
# 85  sfc_salt_flux_coupler     sfc_salt_flux_coupler: flux from the coupler
# 86      sfc_salt_flux_ice                                sfc_salt_flux_ice
# 87  sfc_salt_flux_restore  sfc_salt_flux_restore: flux from restoring term
# 95           surface_salt                               Practical Salinity
#
#     frequency                                             ncfile  # ncfiles  \
# 50  1 monthly               output243/ice/OUTPUT/iceh.2018-12.nc        732
# 51  1 monthly               output243/ice/OUTPUT/iceh.2018-12.nc        732
# 78  1 monthly  output243/ocean/ocean-3d-salt-1-monthly-mean-y...        272
# 85  1 monthly  output243/ocean/ocean-2d-sfc_salt_flux_coupler...        244
# 86  1 monthly  output243/ocean/ocean-2d-sfc_salt_flux_ice-1-m...        244
# 87  1 monthly  output243/ocean/ocean-2d-sfc_salt_flux_restore...        244
# 95  1 monthly  output243/ocean/ocean-2d-surface_salt-1-monthl...        244
#
#              time_start             time_end
# 50  1958-01-01 00:00:00  2019-01-01 00:00:00
# 51  1958-01-01 00:00:00  2019-01-01 00:00:00
# 78  1958-01-01 00:00:00  2019-01-01 00:00:00
# 85  1958-01-01 00:00:00  2019-01-01 00:00:00
# 86  1958-01-01 00:00:00  2019-01-01 00:00:00
# 87  1958-01-01 00:00:00  2019-01-01 00:00:00
# 95  1958-01-01 00:00:00  2019-01-01 00:00:00

# %%
#Getting a list variables that have "ice" in its long_name and that have a monthly frequency
icevar01deg = cc.querying.get_variables(session, experiment = '01deg_jra55v140_iaf', frequency='1 monthly')
icevar01deg[icevar01deg['long_name'].str.lower().str.match('.*ice.*')]
# Out:
#                               name  \
# 7                           Tsfc_m
# 11                          aice_m
# 12                         aicen_m
# 19                         blkmask
# 23                        congel_m
# 41                        frazil_m
# 47                            hi_m
# 50                           lprec
# 52                            melt
# 88               sfc_salt_flux_ice
# 97                       strairx_m
# 98                       strairy_m
# 99                      strength_m
# 126            total_ocean_calving
# 127       total_ocean_calving_heat
# 128  total_ocean_calving_melt_heat
# 139               total_ocean_melt
# 141              total_ocean_river
# 161                         uvel_m
# 165                        vicen_m
# 167                         vvel_m
# 168                        wfiform
# 169                        wfimelt
#
#                                              long_name  frequency  \
# 7                         snow/ice surface temperature  1 monthly
# 11                               ice area  (aggregate)  1 monthly
# 12                                ice area, categories  1 monthly
# 19                                 ice grid block mask  1 monthly
# 23                              congelation ice growth  1 monthly
# 41                                   frazil ice growth  1 monthly
# 47                        grid cell mean ice thickness  1 monthly
# 50   liquid precip (including ice melt/form) into o...  1 monthly
# 52   water flux transferred with sea ice form/melt ...  1 monthly
# 88                                   sfc_salt_flux_ice  1 monthly
# 97                                  atm/ice stress (x)  1 monthly
# 98                                  atm/ice stress (y)  1 monthly
# 99                            compressive ice strength  1 monthly
# 126   total water entering ocean from calving land ice  1 monthly
# 127        total ocean heat flux from calving land ice  1 monthly
# 128  total heat flux to melt frozen land ice (<0 co...  1 monthly
# 139  total liquid water melted from sea ice (>0 ent...  1 monthly
# 141  total liquid river water and calving ice enter...  1 monthly
# 161                                   ice velocity (x)  1 monthly
# 165                             ice volume, categories  1 monthly
# 167                                   ice velocity (y)  1 monthly
# 168  water out of ocean due to ice form (>0 enters ...  1 monthly
# 169  water into ocean due to ice melt (>0 enters oc...  1 monthly
#
#                                    ncfile  # ncfiles           time_start  \
# 7    output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 11   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 12   output197/ice/OUTPUT/iceh.2017-12.nc        374  1986-11-01 00:00:00
# 19   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 23   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 41   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 47   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 50         output197/ocean/ocean_month.nc        197  1984-12-30 00:00:00
# 52         output197/ocean/ocean_month.nc        197  1984-12-30 00:00:00
# 88         output197/ocean/ocean_month.nc        197  1984-12-30 00:00:00
# 97   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 98   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 99   output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 126       output197/ocean/ocean_scalar.nc        197  1984-12-30 00:00:00
# 127       output197/ocean/ocean_scalar.nc        197  1984-12-30 00:00:00
# 128       output197/ocean/ocean_scalar.nc        197  1984-12-30 00:00:00
# 139       output197/ocean/ocean_scalar.nc        197  1984-12-30 00:00:00
# 141       output197/ocean/ocean_scalar.nc        197  1984-12-30 00:00:00
# 161  output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 165  output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 167  output197/ice/OUTPUT/iceh.2017-12.nc        396  1985-01-01 00:00:00
# 168        output197/ocean/ocean_month.nc        197  1984-12-30 00:00:00
# 169        output197/ocean/ocean_month.nc        197  1984-12-30 00:00:00
#
#                 time_end
# 7    2018-01-01 00:00:00
# 11   2018-01-01 00:00:00
# 12   2018-01-01 00:00:00
# 19   2018-01-01 00:00:00
# 23   2018-01-01 00:00:00
# 41   2018-01-01 00:00:00
# 47   2018-01-01 00:00:00
# 50   2017-12-30 00:00:00
# 52   2017-12-30 00:00:00
# 88   2017-12-30 00:00:00
# 97   2018-01-01 00:00:00
# 98   2018-01-01 00:00:00
# 99   2018-01-01 00:00:00
# 126  2017-12-30 00:00:00
# 127  2017-12-30 00:00:00
# 128  2017-12-30 00:00:00
# 139  2017-12-30 00:00:00
# 141  2017-12-30 00:00:00
# 161  2018-01-01 00:00:00
# 165  2018-01-01 00:00:00
# 167  2018-01-01 00:00:00
# 168  2017-12-30 00:00:00
# 169  2017-12-30 00:00:00

# %% [markdown]
# ## Loading data
# The following experiment variables will be used to create plots:
# * **temp** - Conservative monthly temperature
# * **salt** - Practical monthly salinity
# * **aice_m** - Monthly aggregated ice area

# %%
#Removing variables no longer in use
del tempvar01deg, salvar01deg, icevar01deg

# %%
#Creating variables needed to load data with querying.getvar()
expt = '01deg_jra55v140_iaf_cycle2'
temp_var = 'temp'
salt_var = 'salt'
ice_var = 'aice_m'
stime = '2010-01-01' #Only accessing data from 2010 onwards
etime = '2011-12'

# %%
#Loading temperature data
temp_array = cc.querying.getvar(expt, temp_var, session, start_time = stime, end_time = etime, frequency='1 monthly')
temp_array
# Out:
# <xarray.DataArray 'temp' (time: 27, st_ocean: 75, yt_ocean: 2700, xt_ocean: 3600)>
# dask.array<concatenate, shape=(27, 75, 2700, 3600), dtype=float32, chunksize=(1, 19, 135, 180), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
#   * st_ocean  (st_ocean) float64 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) object 2009-10-16 12:00:00 ... 2011-12-16 12:00:00
# Attributes:
#     long_name:      Conservative temperature
#     units:          K
#     valid_range:    [-10. 500.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_t geolat_t
#     standard_name:  sea_water_conservative_temperature

# %%
#Selecting temperature data from the top 10 m of the water column and from 30S towards Antarctica
#Calculating the mean temperatures for the first 10 meters of the water column
SO_temp = temp_array.sel(yt_ocean = slice(-90., -30.), st_ocean = slice(0, 10)).mean("st_ocean")
#Converting temperature from Kelvin to celsius
SO_temp = SO_temp - 273.15
#SO_temp.mean('time').to_dataframe().max(); SO_temp.mean('time').to_dataframe().min()

# %%
meanTempSeason = SO_temp.groupby("time.season").mean("time")

#Create a function to obtain means per season
#def meanSeason(ds):
#    return ds.groupby("time.season").mean('time')

#Group array by year and apply the above function
#meanTempSeason = SO_temp.groupby("time.year").map(meanSeason)

# %%
#Upload library that will give me access to CRS
import cartopy.crs as ccrs
#Upload library that contains shapefiles of terrestrial features
import cartopy.feature as cft

#Define projection to polar
projection = ccrs.SouthPolarStereo()

#Create variable containing the Antarctic continent - 50m is medium scale
land_50m = cft.NaturalEarthFeature('physical', 'land', '50m', edgecolor = 'black', facecolor = 'gray', linewidth = 0.5)

#Create an empty composite figure with 2 rows and 2 columns, set figure size and the projection is set to polar
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (14, 12), subplot_kw = dict(projection = projection))
#Create counter using a list: i and j define the plot, while season refers to season
for i, j, season in [(0, 0, 'DJF'), (1, 1, 'MAM'), (1, 0, 'JJA'), (0, 1, 'SON')]:
    #Extract information for each season and start plotting
    #pcolormesh creates a pseudo color map with a non-rectangular grid
    meanTempSeason.sel(season = season).plot.pcolormesh(
        x = 'xt_ocean', y = 'yt_ocean', ax = axes[i, j], cmap = "Spectral_r", vmin = -10, vmax = 30, 
        ##Allows for a flat map centrered in longitude 0 - this is always needed when plotting a map with cartopy
        transform = ccrs.PlateCarree())
    #Set season as title for each subplot and remove x and y axes labels
    axes[i,j].set_title(season)
    axes[i,j].set_ylabel("")
    axes[i,j].set_xlabel("")

#Changing global parameters
for ax in axes.flat:
    #Set the extent of the maps and set the projection to polar
    ax.set_extent([-280, 80, -80, -40], crs = ccrs.PlateCarree())
    #Add the Antarctic continent
    ax.add_feature(land_50m, color = [0.8, 0.8, 0.8])
    #Adds outlines for the coast
    ax.coastlines(resolution = '50m')

#Removes white space
plt.tight_layout()
#Set title for composite figure
fig.suptitle('Mean seasonal water temperatures (top 10 m) between 2010 and 2011', fontsize = 16)

#Save figure to local folder
plt.savefig("meanTemp.tiff")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-195fbf6e29f6> in <module>
#      11
#      12 #Create an empty composite figure with 2 rows and 2 columns, set figure size and the projection is set to polar
# ---> 13 fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (14, 12), subplot_kw = dict(projection = projection))
#      14 #Create counter using a list: i and j define the plot, while season refers to season
#      15 for i, j, season in [(0, 0, 'DJF'), (1, 1, 'MAM'), (1, 0, 'JJA'), (0, 1, 'SON')]:
#
# NameError: name 'plt' is not defined

# %%
#Loading salinity data
salt_array = cc.querying.getvar(expt, salt_var, session, start_time = stime)
salt_array
# Out:
# <xarray.DataArray 'salt' (time: 96, st_ocean: 75, yt_ocean: 2700, xt_ocean: 3600)>
# dask.array<concatenate, shape=(96, 75, 2700, 3600), dtype=float32, chunksize=(1, 7, 300, 400), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
#   * st_ocean  (st_ocean) float64 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) object 2010-01-14 12:00:00 ... 2017-12-14 12:00:00
# Attributes:
#     long_name:      Practical Salinity
#     units:          psu
#     valid_range:    [-10. 100.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_t geolat_t
#     standard_name:  sea_water_salinity

# %%
#Loading ice area data
ice_array = cc.querying.getvar(expt, ice_var, session, start_time = stime)
ice_array
